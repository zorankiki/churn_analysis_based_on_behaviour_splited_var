# %% [markdown]
# ## Spots that are always excluded:
# ##### Test spots
# ##### Spots marked as problematic
# ##### Suscpicious for analysis == 'Yes' spots
# ##### Fake Sale spots: This means that Reason for Cancelling Survey is any combination which contains 'Fake Sale'
# ##### Spots whose stop date was before 2018
#
#
# ## CAN CANCEL:
# ##### Spots which cancelled more than 2 months before their Available Cancellation Date are excluded
# ##### Spots whose Available Cancellation Date is 2 or more months after the date of analysis
# ##### Months during which spots couldn't have cancelled according to the above conditions
#
# ## wo CB sets:
# ##### Closed Business, Sold Business and Non-payment spots are excluded. This means Reason for Cancelling Survey is any combination which contains 'Closed Business', 'Closed/Sold Business', 'Sold Business', 'Sold/Closed Business' or 'Non-payment'
# ## canc conf event
# ##### Spots for which Date Cancellation Confirmed is more than 60 days after Date Cancellation Requested
#
# #### ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
import pandas as pd
import numpy as np
import importlib
import get_stopped_doing_something_variables
import prepare_for_the_models
import fit_tv_cox_models
#import read_vars_for_separate_models_for_dependent_vars
import read_a_combination_of_variables
import yaml
import warnings
warnings.filterwarnings('ignore')
from IPython.display import display, Markdown

# %%
# read the yaml file with a list of parameters needed for the report
with open(r'./parameters/stopped_doing_something_report_parameters.yaml') as file:
    parameters = yaml.load(file, Loader=yaml.FullLoader)

date_of_analysis = parameters['date_of_analysis']
date_dir = date_of_analysis.replace('-', '_')
### name of the data directory ###
churn_based_on_behaviour_dir = parameters['churn_based_on_behaviour_dir']
### penalizer value when fitting the models ###
penalizer = parameters['penalizer']
### model type ###
model_type = parameters['model_type']
### coefficient and p values when dropping unsignificant variables ###
coefficient_limit_for_numerical_vars = parameters['coefficient_limit_for_numerical_vars']
coefficient_limit_for_cat_vars = parameters['coefficient_limit_for_cat_vars']
p_limit = parameters['p_limit']
additional_higher_p_limit = parameters['additional_higher_p_limit']
additional_lower_p_limit = parameters['additional_lower_p_limit']

# read the yaml file with data set parameters #
# data_set_name = input('Data set name: ')
data_set_name = 'ALL_spots_with_CB_cancellation_confirmed'
with open(r'./parameters/data_sets.yaml') as file:
    data_sets_parameters = yaml.load(file, Loader=yaml.FullLoader)
    
spots_set = data_sets_parameters[data_set_name]['spots_set']
with_wo_CB = data_sets_parameters[data_set_name]['with_wo_CB']
event_date_full_name = data_sets_parameters[data_set_name]['event_date_type']

if with_wo_CB == 'with_CB':
    with_wo_CB_boolean = True
else:
    with_wo_CB_boolean = False

if event_date_full_name == 'cancellation_requested':
    event_date = 'canc_req'
elif event_date_full_name == 'cancellation_confirmed':
    event_date = 'canc_conf'

##### base columns ##### 
base_cols = ['spot_id',\
            'time',\
            'event']

# %%
##### Model 0: all variables - prepare data for the model ####
# cols_to_use = read_vars_for_separate_models_for_dependent_vars.\
# main(model_number=0, dir_name='separate_models_for_dependent_variables/')
cols_to_use = read_a_combination_of_variables.\
main(model_number=0, dir_name='combinations_of_variables_that_are_not_dependent/')
#### get behavioural variables ####
(variables_to_use_for_the_model, did_something_before_vars, did_something_last_month_vars) = \
get_stopped_doing_something_variables.main(date_of_analysis=date_of_analysis, variables_to_use_for_the_model=cols_to_use)
cols = base_cols + variables_to_use_for_the_model + \
did_something_before_vars + did_something_last_month_vars


#### get data for the model ###
(data, base_df, df_timeline_all_vars) = \
prepare_for_the_models.get_data_for_the_MV_Cox_model(date_of_analysis=date_of_analysis, spots_set=spots_set, \
                            with_wo_CB=with_wo_CB, event_date=event_date, columns=cols, data_dir=churn_based_on_behaviour_dir,\
                            C = 100)
    
model_numbers = \
read_a_combination_of_variables.get_a_list_of_model_numbers(dir_name='combinations_of_variables_that_are_not_dependent/')


## save the initial set of all variables - dependent ones included ##
original_cols = [x for x in df_timeline_all_vars.columns.tolist() if x not in ['spot_id', 'event', 'start', 'stop']]

# %%
number_of_models = len(model_numbers[1:])
(all_models_summaries, all_models_names, conditions_described) = \
fit_tv_cox_models.\
fit_all_models_and_get_all_summaries(number_of_models=number_of_models, model_numbers=model_numbers, \
                                     date_of_analysis=date_of_analysis, churn_based_on_behaviour_dir=churn_based_on_behaviour_dir,\
                                     spots_set=spots_set, with_wo_CB=with_wo_CB, event_date_full_name=event_date_full_name, \
                                     df_timeline_all_vars=df_timeline_all_vars, base_cols=base_cols, base_df=base_df, \
                                     model_type=model_type, coefficient_limit_for_numerical_vars=coefficient_limit_for_numerical_vars,\
                                     coefficient_limit_for_cat_vars=coefficient_limit_for_cat_vars, p_limit=p_limit,\
                                     additional_higher_p_limit=additional_higher_p_limit, additional_lower_p_limit=additional_lower_p_limit, \
                                     penalizer=penalizer)

# %%
### calculate average coefficients and p values for each variable ###
summary_cols = ['variable', 'coef - AVERAGE', 'exp(coef) - AVERAGE', 'p value - AVERAGE']
final_summaries = []
all_conditions_described = []
summary_cols = ['variable', 'coef - AVERAGE', 'exp(coef) - AVERAGE', 'p value - AVERAGE']
final_summaries = []
for key in all_models_summaries.keys():
    all_conditions_described.append(conditions_described[key])
    final_summary = pd.DataFrame(columns=summary_cols)
    final_summary['variable'] = original_cols
    final_summary.set_index('variable', inplace = True)
    
    all_coef_for_each_var = dict.fromkeys(original_cols)
    all_exp_coef_for_each_var = dict.fromkeys(original_cols)
    all_p_value_for_each_var = dict.fromkeys(original_cols)

    for col in original_cols:
        all_coef_for_each_var[col] = []
        all_exp_coef_for_each_var[col] = []
        all_p_value_for_each_var[col] = []
        
    for var_ in original_cols:
        for summary_ in all_models_summaries[key]:
            if var_ in summary_.index.unique():
                all_coef_for_each_var[var_].append(summary_.loc[var_, 'coef'])
                all_exp_coef_for_each_var[var_].append(summary_.loc[var_, 'exp(coef)'])
                all_p_value_for_each_var[var_].append(summary_.loc[var_, 'p'])
        final_summary.loc[var_, 'coef - AVERAGE'] = round(np.mean(np.array(all_coef_for_each_var[var_])), 3)
        final_summary.loc[var_, 'exp(coef) - AVERAGE'] = round(np.mean(np.array(all_exp_coef_for_each_var[var_])), 3)
        final_summary.loc[var_, 'p value - AVERAGE'] = round(np.mean(np.array(all_p_value_for_each_var[var_])), 3)
        
    final_summary.drop(final_summary[final_summary['coef - AVERAGE'].isnull()].index, inplace = True)
    #display(final_summary)
    final_summaries.append(final_summary)

# %% [markdown]
# # Average coefficients and p values for all combinations of variables - sorted by p value

# %%
pd.set_option('display.max_rows', 500)
for i in range(0, len(final_summaries)):
    display(Markdown("## "+all_conditions_described[i]))
    display(final_summaries[i].sort_values('p value - AVERAGE'))
# Out:
# ## with all initial variables
#                                                    coef - AVERAGE  \
# variable
# had_tickets_before                                         -0.638
# had_posts_on_facebook_last_month                           -0.597
# had_clicked_emails_last_3_months                            -0.57
# Website.Views.last.month.total.log2                        -0.223
# their_own_website_no                                       -1.957
# Monthly                                                     1.003
# metro_area_Atlanta                                         -0.893
# spot_category_Mexican / Latin                               0.742
# their_own_website_dontKnow                                  -1.04
# had_visited_qrcode_flyers_page_before                      -0.841
# had_clicked_emails_before                                   0.411
# metro_area_Boston                                           0.669
# metro_area_Portland                                        -0.728
# spot_category_Pub                                          -1.617
# had_posts_liked_last_3_months                              -0.491
# had_posts_on_facebook_before                                0.362
# Fb.page.likes.analysis.avg.log2                            -0.038
# spot_category_Thai                                          0.821
# had_preview_page_views_before                               0.527
# had_added_specials_edited_specials_last_3_months            0.496
# metro_area_New Orleans                                     -1.863
# metro_area_Detroit                                         -0.704
# had_visited_special_page_last_3_months                     -0.394
# metro_area_other                                           -0.483
# had_reservations_submissions_before                         0.358
# spot_category_Pizza                                        -0.586
# Instagram.Add.on                                            0.211
# had_reservations_submissions_last_month                    -0.555
# had_visited_stats_page_last_3_months                         0.28
# had_qr_code_menu_scans_before                              -0.458
# spot_category_Sushi                                        -1.468
# is_platform_only                                           -0.483
# had_emails_sent_manually_scheduled_emails_sent_...         -0.246
# had_visited_admin_before                                    0.369
# is_premium_plus                                            -0.198
# had_catering_submissions_last_3_months                     -0.368
# had_other_non_contactless_menu_qr_flyer_scans_l...         -1.019
# had_visited_regular_flyers_page_before                      0.225
# had_added_events_manually_edited_events_last_3_...          -0.36
# had_visited_admin_last_month                                -0.19
# had_visited_inquiries_pages_last_3_months                  -0.249
# had_added_specials_edited_specials_before                  -0.179
# metro_area_Dallas                                          -0.365
# had_other_non_contactless_menu_qr_flyer_scans_b...          0.471
# had_consumer_job_listing_inquiries_before                   0.298
# metro_area_Milwaukee                                       -0.676
# had_visited_special_page_before                            -0.215
# had_downloaded_regular_flyers_before                         0.21
# metro_area_Chicago                                         -0.326
# metro_area_Houston                                         -0.382
# New.email.subscribers.allinclusive.last.month.d...         -0.062
# metro_area_Phoenix                                         -0.244
# spot_category_American Restaurant / Bar                    -0.251
# had_online_orders_before                                     0.31
# spot_category_Gastropub                                     0.395
# had_added_food_edited_food_before                           0.162
# had_posts_seen_before                                       0.267
# had_visited_food_page_last_3_months                        -0.207
# had_visited_regular_flyers_page_last_3_months              -0.206
# had_posts_disliked_last_3_months                             0.21
# had_added_events_manually_edited_events_before              0.145
# spot_category_Sports Bar                                   -0.261
# spot_category_Japanese                                      0.411
# spot_category_Steakhouse                                   -0.632
# had_online_orders_last_month                               -0.336
# had_catering_submissions_before                            -0.169
# had_changed_picture_or_text_last_3_months                  -0.184
# had_opened_rewarding_stats_emails_before                    0.258
# metro_area_Denver                                          -0.417
# spot_category_Bar                                           0.183
# spot_category_Irish Pub                                    -0.259
# had_number_of_requests_for_new_text_fragment_la...          0.196
# had_visited_food_page_before                               -0.124
# metro_area_Austin                                          -0.177
# spot_category_other                                         0.123
# metro_area_Minneapolis                                     -0.295
# Opted.out.of.facebook                                       0.126
# had_visited_inquiries_pages_before                          0.097
# had_preview_page_views_last_3_months                       -0.127
# had_downloaded_qrcode_flyers_last_2_months                  0.449
# had_number_of_requests_for_new_text_fragment_be...          0.088
# metro_area_Washington DC                                   -0.213
# Annual Commitment with 2 semi-annual payments               -0.19
# metro_area_Los Angeles                                     -0.099
# had_opened_rewarding_stats_emails_last_2_months             0.186
# SpotHopper_site_not_live_yet                               -0.168
# had_flyer_posts_on_facebook_before                         -0.079
# had_posts_disliked_before                                   0.082
# metro_area_Charlotte                                        0.212
# had_flyer_posts_on_facebook_last_2_months                  -0.233
# had_visited_events_page_before                               0.07
# had_consumer_job_listing_inquiries_last_2_months             0.12
# Annual Prepay                                              -0.054
# spot_category_Breakfast / Brunch                             0.18
# had_visited_events_page_last_3_months                       0.066
# had_emails_sent_manually_scheduled_emails_sent_...          0.041
# is_corona                                                  -0.019
# had_added_food_edited_food_last_3_months                    0.057
# had_downloaded_qrcode_flyers_before                        -0.157
# spot_category_Asian                                         -0.14
# metro_area_New York                                        -0.049
# had_private_parties_submissions_before                     -0.039
# spot_category_American Restaurant                          -0.058
# spot_category_BBQ                                           0.088
# spot_category_Cafe                                         -0.082
# had_visited_stats_page_before                              -0.012
# spot_category_Brewery                                       0.092
# metro_area_Charleston                                       0.069
# spot_category_Italian                                      -0.045
# had_changed_picture_or_text_before                          0.032
# had_tickets_last_3_months                                   0.021
# had_downloaded_regular_flyers_last_3_months                 0.063
# had_posts_liked_before                                      0.015
# had_qr_code_menu_scans_last_month                           -0.04
# had_posts_seen_last_3_months                               -0.015
# had_feedback_submissions_before                            -8.874
# spot_category_Restaurant                                    0.022
# New.email.subscriber.signups.last.month.div10                   0
# spot_category_Seafood                                      -0.022
# had_incentive_downloads_before                             -8.837
# had_private_parties_submissions_last_2_months               0.003
# had_bday_club_downloads_before                             -7.171
# had_visited_qrcode_flyers_page_last_3_months               -0.017
# had_bday_club_downloads_last_month                         -2.774
# had_feedback_submissions_last_month                        -1.653
# had_incentive_downloads_last_month                         -1.726
#
#                                                    exp(coef) - AVERAGE  \
# variable
# had_tickets_before                                               0.529
# had_posts_on_facebook_last_month                                 0.551
# had_clicked_emails_last_3_months                                 0.566
# Website.Views.last.month.total.log2                                0.8
# their_own_website_no                                             0.141
# Monthly                                                          2.726
# metro_area_Atlanta                                               0.409
# spot_category_Mexican / Latin                                    2.103
# their_own_website_dontKnow                                       0.354
# had_visited_qrcode_flyers_page_before                            0.432
# had_clicked_emails_before                                        1.511
# metro_area_Boston                                                1.954
# metro_area_Portland                                              0.484
# spot_category_Pub                                                0.199
# had_posts_liked_last_3_months                                    0.612
# had_posts_on_facebook_before                                     1.438
# Fb.page.likes.analysis.avg.log2                                  0.963
# spot_category_Thai                                               2.274
# had_preview_page_views_before                                    1.697
# had_added_specials_edited_specials_last_3_months                 1.643
# metro_area_New Orleans                                           0.155
# metro_area_Detroit                                               0.495
# had_visited_special_page_last_3_months                           0.675
# metro_area_other                                                 0.618
# had_reservations_submissions_before                              1.431
# spot_category_Pizza                                              0.557
# Instagram.Add.on                                                 1.236
# had_reservations_submissions_last_month                          0.575
# had_visited_stats_page_last_3_months                             1.324
# had_qr_code_menu_scans_before                                    0.633
# spot_category_Sushi                                              0.231
# is_platform_only                                                 0.618
# had_emails_sent_manually_scheduled_emails_sent_...               0.783
# had_visited_admin_before                                         1.452
# is_premium_plus                                                  0.821
# had_catering_submissions_last_3_months                           0.692
# had_other_non_contactless_menu_qr_flyer_scans_l...               0.361
# had_visited_regular_flyers_page_before                           1.253
# had_added_events_manually_edited_events_last_3_...               0.698
# had_visited_admin_last_month                                     0.828
# had_visited_inquiries_pages_last_3_months                         0.78
# had_added_specials_edited_specials_before                        0.837
# metro_area_Dallas                                                0.694
# had_other_non_contactless_menu_qr_flyer_scans_b...               1.609
# had_consumer_job_listing_inquiries_before                        1.348
# metro_area_Milwaukee                                              0.51
# had_visited_special_page_before                                  0.807
# had_downloaded_regular_flyers_before                             1.234
# metro_area_Chicago                                               0.722
# metro_area_Houston                                               0.683
# New.email.subscribers.allinclusive.last.month.d...                0.94
# metro_area_Phoenix                                               0.784
# spot_category_American Restaurant / Bar                          0.779
# had_online_orders_before                                         1.364
# spot_category_Gastropub                                          1.486
# had_added_food_edited_food_before                                1.177
# had_posts_seen_before                                            1.314
# had_visited_food_page_last_3_months                              0.813
# had_visited_regular_flyers_page_last_3_months                    0.814
# had_posts_disliked_last_3_months                                 1.235
# had_added_events_manually_edited_events_before                   1.156
# spot_category_Sports Bar                                         0.771
# spot_category_Japanese                                           1.513
# spot_category_Steakhouse                                         0.532
# had_online_orders_last_month                                     0.715
# had_catering_submissions_before                                  0.844
# had_changed_picture_or_text_last_3_months                        0.833
# had_opened_rewarding_stats_emails_before                         1.298
# metro_area_Denver                                                 0.66
# spot_category_Bar                                                1.202
# spot_category_Irish Pub                                          0.773
# had_number_of_requests_for_new_text_fragment_la...               1.217
# had_visited_food_page_before                                     0.884
# metro_area_Austin                                                0.838
# spot_category_other                                              1.131
# metro_area_Minneapolis                                           0.745
# Opted.out.of.facebook                                            1.134
# had_visited_inquiries_pages_before                               1.103
# had_preview_page_views_last_3_months                             0.881
# had_downloaded_qrcode_flyers_last_2_months                       1.569
# had_number_of_requests_for_new_text_fragment_be...               1.093
# metro_area_Washington DC                                          0.81
# Annual Commitment with 2 semi-annual payments                    0.828
# metro_area_Los Angeles                                           0.907
# had_opened_rewarding_stats_emails_last_2_months                  1.204
# SpotHopper_site_not_live_yet                                     0.846
# had_flyer_posts_on_facebook_before                               0.925
# had_posts_disliked_before                                        1.087
# metro_area_Charlotte                                             1.239
# had_flyer_posts_on_facebook_last_2_months                        0.794
# had_visited_events_page_before                                   1.073
# had_consumer_job_listing_inquiries_last_2_months                 1.128
# Annual Prepay                                                    0.948
# spot_category_Breakfast / Brunch                                 1.198
# had_visited_events_page_last_3_months                            1.068
# had_emails_sent_manually_scheduled_emails_sent_...               1.043
# is_corona                                                        0.982
# had_added_food_edited_food_last_3_months                         1.059
# had_downloaded_qrcode_flyers_before                              0.859
# spot_category_Asian                                              0.873
# metro_area_New York                                              0.952
# had_private_parties_submissions_before                           0.962
# spot_category_American Restaurant                                0.944
# spot_category_BBQ                                                1.094
# spot_category_Cafe                                               0.923
# had_visited_stats_page_before                                    0.989
# spot_category_Brewery                                            1.097
# metro_area_Charleston                                            1.074
# spot_category_Italian                                            0.957
# had_changed_picture_or_text_before                               1.033
# had_tickets_last_3_months                                        1.021
# had_downloaded_regular_flyers_last_3_months                      1.066
# had_posts_liked_before                                           1.016
# had_qr_code_menu_scans_last_month                                0.961
# had_posts_seen_last_3_months                                     0.986
# had_feedback_submissions_before                                      0
# spot_category_Restaurant                                         1.023
# New.email.subscriber.signups.last.month.div10                    1.001
# spot_category_Seafood                                            0.979
# had_incentive_downloads_before                                       0
# had_private_parties_submissions_last_2_months                    1.003
# had_bday_club_downloads_before                                   0.001
# had_visited_qrcode_flyers_page_last_3_months                     0.984
# had_bday_club_downloads_last_month                               0.063
# had_feedback_submissions_last_month                              0.194
# had_incentive_downloads_last_month                               0.178
#
#                                                    p value - AVERAGE
# variable
# had_tickets_before                                                 0
# had_posts_on_facebook_last_month                                   0
# had_clicked_emails_last_3_months                                   0
# Website.Views.last.month.total.log2                                0
# their_own_website_no                                               0
# Monthly                                                            0
# metro_area_Atlanta                                             0.002
# spot_category_Mexican / Latin                                  0.003
# their_own_website_dontKnow                                     0.006
# had_visited_qrcode_flyers_page_before                          0.011
# had_clicked_emails_before                                      0.015
# metro_area_Boston                                              0.021
# metro_area_Portland                                            0.026
# spot_category_Pub                                              0.029
# had_posts_liked_last_3_months                                   0.04
# had_posts_on_facebook_before                                   0.041
# Fb.page.likes.analysis.avg.log2                                0.043
# spot_category_Thai                                             0.057
# had_preview_page_views_before                                  0.059
# had_added_specials_edited_specials_last_3_months               0.066
# metro_area_New Orleans                                         0.068
# metro_area_Detroit                                             0.075
# had_visited_special_page_last_3_months                         0.079
# metro_area_other                                                0.09
# had_reservations_submissions_before                            0.116
# spot_category_Pizza                                            0.127
# Instagram.Add.on                                               0.135
# had_reservations_submissions_last_month                        0.141
# had_visited_stats_page_last_3_months                           0.151
# had_qr_code_menu_scans_before                                  0.151
# spot_category_Sushi                                            0.153
# is_platform_only                                               0.173
# had_emails_sent_manually_scheduled_emails_sent_...             0.177
# had_visited_admin_before                                       0.184
# is_premium_plus                                                0.199
# had_catering_submissions_last_3_months                         0.208
# had_other_non_contactless_menu_qr_flyer_scans_l...              0.21
# had_visited_regular_flyers_page_before                         0.214
# had_added_events_manually_edited_events_last_3_...             0.215
# had_visited_admin_last_month                                   0.226
# had_visited_inquiries_pages_last_3_months                       0.24
# had_added_specials_edited_specials_before                      0.249
# metro_area_Dallas                                              0.255
# had_other_non_contactless_menu_qr_flyer_scans_b...              0.26
# had_consumer_job_listing_inquiries_before                      0.262
# metro_area_Milwaukee                                           0.267
# had_visited_special_page_before                                0.278
# had_downloaded_regular_flyers_before                           0.282
# metro_area_Chicago                                              0.29
# metro_area_Houston                                              0.29
# New.email.subscribers.allinclusive.last.month.d...               0.3
# metro_area_Phoenix                                             0.303
# spot_category_American Restaurant / Bar                        0.306
# had_online_orders_before                                       0.329
# spot_category_Gastropub                                        0.331
# had_added_food_edited_food_before                              0.333
# had_posts_seen_before                                          0.335
# had_visited_food_page_last_3_months                            0.359
# had_visited_regular_flyers_page_last_3_months                  0.369
# had_posts_disliked_last_3_months                               0.369
# had_added_events_manually_edited_events_before                 0.397
# spot_category_Sports Bar                                       0.409
# spot_category_Japanese                                         0.411
# spot_category_Steakhouse                                       0.417
# had_online_orders_last_month                                   0.464
# had_catering_submissions_before                                0.467
# had_changed_picture_or_text_last_3_months                      0.491
# had_opened_rewarding_stats_emails_before                       0.491
# metro_area_Denver                                              0.494
# spot_category_Bar                                              0.501
# spot_category_Irish Pub                                         0.51
# had_number_of_requests_for_new_text_fragment_la...             0.519
# had_visited_food_page_before                                   0.526
# metro_area_Austin                                               0.54
# spot_category_other                                            0.543
# metro_area_Minneapolis                                         0.543
# Opted.out.of.facebook                                          0.571
# had_visited_inquiries_pages_before                              0.58
# had_preview_page_views_last_3_months                           0.584
# had_downloaded_qrcode_flyers_last_2_months                     0.591
# had_number_of_requests_for_new_text_fragment_be...             0.601
# metro_area_Washington DC                                       0.607
# Annual Commitment with 2 semi-annual payments                  0.645
# metro_area_Los Angeles                                         0.648
# had_opened_rewarding_stats_emails_last_2_months                0.649
# SpotHopper_site_not_live_yet                                   0.656
# had_flyer_posts_on_facebook_before                             0.664
# had_posts_disliked_before                                      0.671
# metro_area_Charlotte                                             0.7
# had_flyer_posts_on_facebook_last_2_months                      0.709
# had_visited_events_page_before                                 0.713
# had_consumer_job_listing_inquiries_last_2_months               0.716
# Annual Prepay                                                  0.724
# spot_category_Breakfast / Brunch                                0.74
# had_visited_events_page_last_3_months                          0.753
# had_emails_sent_manually_scheduled_emails_sent_...             0.758
# is_corona                                                      0.779
# had_added_food_edited_food_last_3_months                       0.787
# had_downloaded_qrcode_flyers_before                             0.79
# spot_category_Asian                                            0.797
# metro_area_New York                                            0.806
# had_private_parties_submissions_before                         0.828
# spot_category_American Restaurant                              0.829
# spot_category_BBQ                                              0.831
# spot_category_Cafe                                             0.834
# had_visited_stats_page_before                                  0.838
# spot_category_Brewery                                          0.841
# metro_area_Charleston                                          0.852
# spot_category_Italian                                          0.852
# had_changed_picture_or_text_before                             0.858
# had_tickets_last_3_months                                      0.876
# had_downloaded_regular_flyers_last_3_months                    0.889
# had_posts_liked_before                                         0.896
# had_qr_code_menu_scans_last_month                              0.911
# had_posts_seen_last_3_months                                   0.911
# had_feedback_submissions_before                                0.916
# spot_category_Restaurant                                       0.921
# New.email.subscriber.signups.last.month.div10                  0.927
# spot_category_Seafood                                          0.931
# had_incentive_downloads_before                                 0.936
# had_private_parties_submissions_last_2_months                  0.952
# had_bday_club_downloads_before                                 0.962
# had_visited_qrcode_flyers_page_last_3_months                   0.963
# had_bday_club_downloads_last_month                             0.992
# had_feedback_submissions_last_month                            0.994
# had_incentive_downloads_last_month                             0.995
# ## without categorical variables with |coeff| < 0.2 and p value > 0.2; without numerical variables with |coeff| < 0.01 and p value > 0.2
#                                                    coef - AVERAGE  \
# variable
# their_own_website_no                                       -1.816
# had_posts_on_facebook_last_month                            -0.61
# Monthly                                                     1.021
# had_tickets_before                                         -0.633
# had_clicked_emails_last_3_months                           -0.587
# Website.Views.last.month.total.log2                        -0.219
# spot_category_Mexican / Latin                               0.678
# metro_area_Atlanta                                         -0.788
# their_own_website_dontKnow                                 -1.043
# metro_area_Boston                                           0.732
# had_visited_qrcode_flyers_page_before                      -0.852
# had_clicked_emails_before                                   0.416
# had_posts_liked_last_3_months                              -0.522
# spot_category_Pub                                          -1.612
# had_posts_on_facebook_before                                0.367
# metro_area_Portland                                         -0.61
# had_visited_special_page_last_3_months                     -0.413
# had_preview_page_views_before                               0.544
# Fb.page.likes.analysis.avg.log2                            -0.036
# spot_category_Thai                                          0.732
# had_changed_picture_or_text_last_3_months                  -0.415
# had_added_specials_edited_specials_last_3_months             0.48
# metro_area_New Orleans                                     -1.767
# is_premium_plus                                            -0.247
# metro_area_Detroit                                         -0.649
# spot_category_Pizza                                        -0.597
# Instagram.Add.on                                            0.226
# had_visited_regular_flyers_page_before                      0.268
# had_reservations_submissions_last_month                    -0.575
# had_reservations_submissions_before                          0.34
# metro_area_other                                           -0.403
# spot_category_Sushi                                        -1.543
# spot_category_American Restaurant / Bar                    -0.295
# had_emails_sent_manually_scheduled_emails_sent_...         -0.266
# had_qr_code_menu_scans_before                               -0.46
# had_visited_food_page_last_3_months                        -0.227
# had_visited_stats_page_last_3_months                        0.271
# had_visited_admin_last_month                               -0.208
# New.email.subscribers.allinclusive.last.month.d...         -0.061
# had_changed_picture_or_text_before                          0.201
# had_catering_submissions_last_3_months                     -0.378
# is_platform_only                                           -0.439
# had_added_events_manually_edited_events_last_3_...         -0.341
# had_visited_inquiries_pages_last_3_months                  -0.265
# had_other_non_contactless_menu_qr_flyer_scans_l...         -1.022
# had_visited_admin_before                                    0.341
# had_consumer_job_listing_inquiries_before                    0.32
# had_number_of_requests_for_new_text_fragment_la...          0.323
# had_downloaded_regular_flyers_before                        0.223
# metro_area_Phoenix                                         -0.237
# had_added_events_manually_edited_events_before              0.183
# metro_area_Dallas                                          -0.339
# had_other_non_contactless_menu_qr_flyer_scans_b...          0.448
# had_posts_disliked_last_3_months                            0.209
# spot_category_Bar                                           0.228
# spot_category_Gastropub                                     0.374
# spot_category_Sports Bar                                   -0.277
# had_online_orders_before                                    0.306
# had_posts_seen_before                                       0.267
# had_visited_special_page_before                            -0.173
# metro_area_Milwaukee                                       -0.569
# had_added_specials_edited_specials_before                  -0.143
# spot_category_Irish Pub                                    -0.334
# metro_area_Chicago                                         -0.259
# had_posts_disliked_before                                   0.144
# had_visited_regular_flyers_page_last_3_months               -0.19
# spot_category_Steakhouse                                   -0.648
# metro_area_Houston                                         -0.286
# metro_area_Charleston                                       0.318
# spot_category_Japanese                                      0.362
# SpotHopper_site_not_live_yet                               -0.277
# had_online_orders_last_month                               -0.342
# had_number_of_requests_for_new_text_fragment_be...          0.113
# had_opened_rewarding_stats_emails_before                    0.261
# had_catering_submissions_before                            -0.154
# had_preview_page_views_last_3_months                       -0.141
# spot_category_Asian                                        -0.349
# metro_area_Washington DC                                   -0.249
# metro_area_Charlotte                                        0.338
# Annual Commitment with 2 semi-annual payments              -0.253
# had_visited_inquiries_pages_before                          0.088
# had_downloaded_qrcode_flyers_last_2_months                  0.453
# metro_area_Denver                                          -0.323
# metro_area_Minneapolis                                     -0.232
# had_opened_rewarding_stats_emails_last_2_months             0.193
# had_flyer_posts_on_facebook_before                         -0.077
# had_flyer_posts_on_facebook_last_2_months                  -0.284
# had_visited_food_page_before                               -0.077
# spot_category_Breakfast / Brunch                            0.225
# had_emails_sent_manually_scheduled_emails_sent_...          0.045
# New.email.subscriber.signups.last.month.div10              -0.012
# had_posts_liked_before                                      0.041
# had_downloaded_qrcode_flyers_before                        -0.141
# had_consumer_job_listing_inquiries_last_2_months            0.079
# had_visited_stats_page_before                               0.005
# had_tickets_last_3_months                                   0.023
# had_qr_code_menu_scans_last_month                          -0.059
# had_posts_seen_last_3_months                                -0.02
# had_feedback_submissions_before                             -8.83
# had_incentive_downloads_before                             -8.858
# had_downloaded_regular_flyers_last_3_months                 0.009
# had_visited_qrcode_flyers_page_last_3_months               -0.025
# had_bday_club_downloads_before                              -7.23
# had_bday_club_downloads_last_month                         -2.701
# had_feedback_submissions_last_month                        -1.684
# had_incentive_downloads_last_month                         -1.718
#
#                                                    exp(coef) - AVERAGE  \
# variable
# their_own_website_no                                             0.164
# had_posts_on_facebook_last_month                                 0.543
# Monthly                                                          2.777
# had_tickets_before                                               0.531
# had_clicked_emails_last_3_months                                 0.556
# Website.Views.last.month.total.log2                              0.804
# spot_category_Mexican / Latin                                    1.972
# metro_area_Atlanta                                               0.455
# their_own_website_dontKnow                                       0.353
# metro_area_Boston                                                 2.08
# had_visited_qrcode_flyers_page_before                            0.427
# had_clicked_emails_before                                        1.517
# had_posts_liked_last_3_months                                    0.594
# spot_category_Pub                                                  0.2
# had_posts_on_facebook_before                                     1.445
# metro_area_Portland                                              0.544
# had_visited_special_page_last_3_months                           0.662
# had_preview_page_views_before                                    1.729
# Fb.page.likes.analysis.avg.log2                                  0.965
# spot_category_Thai                                               2.081
# had_changed_picture_or_text_last_3_months                         0.66
# had_added_specials_edited_specials_last_3_months                 1.618
# metro_area_New Orleans                                           0.171
# is_premium_plus                                                  0.781
# metro_area_Detroit                                               0.523
# spot_category_Pizza                                              0.551
# Instagram.Add.on                                                 1.253
# had_visited_regular_flyers_page_before                           1.308
# had_reservations_submissions_last_month                          0.563
# had_reservations_submissions_before                              1.406
# metro_area_other                                                 0.668
# spot_category_Sushi                                              0.214
# spot_category_American Restaurant / Bar                          0.745
# had_emails_sent_manually_scheduled_emails_sent_...               0.768
# had_qr_code_menu_scans_before                                    0.631
# had_visited_food_page_last_3_months                              0.797
# had_visited_stats_page_last_3_months                             1.312
# had_visited_admin_last_month                                     0.813
# New.email.subscribers.allinclusive.last.month.d...               0.941
# had_changed_picture_or_text_before                               1.222
# had_catering_submissions_last_3_months                           0.685
# is_platform_only                                                 0.647
# had_added_events_manually_edited_events_last_3_...               0.712
# had_visited_inquiries_pages_last_3_months                        0.768
# had_other_non_contactless_menu_qr_flyer_scans_l...                0.36
# had_visited_admin_before                                         1.412
# had_consumer_job_listing_inquiries_before                        1.378
# had_number_of_requests_for_new_text_fragment_la...               1.381
# had_downloaded_regular_flyers_before                              1.25
# metro_area_Phoenix                                               0.789
# had_added_events_manually_edited_events_before                   1.201
# metro_area_Dallas                                                0.714
# had_other_non_contactless_menu_qr_flyer_scans_b...               1.572
# had_posts_disliked_last_3_months                                 1.235
# spot_category_Bar                                                1.256
# spot_category_Gastropub                                          1.456
# spot_category_Sports Bar                                         0.759
# had_online_orders_before                                         1.359
# had_posts_seen_before                                            1.316
# had_visited_special_page_before                                  0.842
# metro_area_Milwaukee                                             0.567
# had_added_specials_edited_specials_before                        0.867
# spot_category_Irish Pub                                          0.717
# metro_area_Chicago                                               0.772
# had_posts_disliked_before                                        1.156
# had_visited_regular_flyers_page_last_3_months                    0.828
# spot_category_Steakhouse                                         0.525
# metro_area_Houston                                               0.752
# metro_area_Charleston                                            1.375
# spot_category_Japanese                                           1.439
# SpotHopper_site_not_live_yet                                     0.758
# had_online_orders_last_month                                     0.711
# had_number_of_requests_for_new_text_fragment_be...                1.12
# had_opened_rewarding_stats_emails_before                         1.298
# had_catering_submissions_before                                  0.858
# had_preview_page_views_last_3_months                             0.869
# spot_category_Asian                                              0.707
# metro_area_Washington DC                                          0.78
# metro_area_Charlotte                                             1.404
# Annual Commitment with 2 semi-annual payments                    0.777
# had_visited_inquiries_pages_before                               1.094
# had_downloaded_qrcode_flyers_last_2_months                       1.575
# metro_area_Denver                                                0.725
# metro_area_Minneapolis                                           0.793
# had_opened_rewarding_stats_emails_last_2_months                  1.213
# had_flyer_posts_on_facebook_before                               0.928
# had_flyer_posts_on_facebook_last_2_months                        0.755
# had_visited_food_page_before                                     0.926
# spot_category_Breakfast / Brunch                                 1.252
# had_emails_sent_manually_scheduled_emails_sent_...               1.048
# New.email.subscriber.signups.last.month.div10                    0.988
# had_posts_liked_before                                           1.043
# had_downloaded_qrcode_flyers_before                              0.872
# had_consumer_job_listing_inquiries_last_2_months                 1.082
# had_visited_stats_page_before                                    1.006
# had_tickets_last_3_months                                        1.024
# had_qr_code_menu_scans_last_month                                0.943
# had_posts_seen_last_3_months                                     0.981
# had_feedback_submissions_before                                      0
# had_incentive_downloads_before                                       0
# had_downloaded_regular_flyers_last_3_months                       1.01
# had_visited_qrcode_flyers_page_last_3_months                     0.976
# had_bday_club_downloads_before                                   0.001
# had_bday_club_downloads_last_month                               0.068
# had_feedback_submissions_last_month                              0.188
# had_incentive_downloads_last_month                                0.18
#
#                                                    p value - AVERAGE
# variable
# their_own_website_no                                               0
# had_posts_on_facebook_last_month                                   0
# Monthly                                                            0
# had_tickets_before                                                 0
# had_clicked_emails_last_3_months                                   0
# Website.Views.last.month.total.log2                                0
# spot_category_Mexican / Latin                                  0.001
# metro_area_Atlanta                                             0.003
# their_own_website_dontKnow                                     0.004
# metro_area_Boston                                              0.005
# had_visited_qrcode_flyers_page_before                          0.008
# had_clicked_emails_before                                      0.012
# had_posts_liked_last_3_months                                  0.019
# spot_category_Pub                                              0.025
# had_posts_on_facebook_before                                   0.032
# metro_area_Portland                                             0.04
# had_visited_special_page_last_3_months                         0.048
# had_preview_page_views_before                                  0.049
# Fb.page.likes.analysis.avg.log2                                 0.05
# spot_category_Thai                                             0.057
# had_changed_picture_or_text_last_3_months                       0.06
# had_added_specials_edited_specials_last_3_months               0.072
# metro_area_New Orleans                                         0.082
# is_premium_plus                                                0.084
# metro_area_Detroit                                             0.086
# spot_category_Pizza                                            0.089
# Instagram.Add.on                                               0.089
# had_visited_regular_flyers_page_before                         0.106
# had_reservations_submissions_last_month                        0.113
# had_reservations_submissions_before                            0.117
# metro_area_other                                               0.122
# spot_category_Sushi                                            0.128
# spot_category_American Restaurant / Bar                         0.13
# had_emails_sent_manually_scheduled_emails_sent_...              0.14
# had_qr_code_menu_scans_before                                  0.144
# had_visited_food_page_last_3_months                            0.157
# had_visited_stats_page_last_3_months                           0.157
# had_visited_admin_last_month                                   0.158
# New.email.subscribers.allinclusive.last.month.d...             0.168
# had_changed_picture_or_text_before                              0.18
# had_catering_submissions_last_3_months                         0.191
# is_platform_only                                               0.193
# had_added_events_manually_edited_events_last_3_...             0.196
# had_visited_inquiries_pages_last_3_months                      0.202
# had_other_non_contactless_menu_qr_flyer_scans_l...             0.207
# had_visited_admin_before                                       0.208
# had_consumer_job_listing_inquiries_before                      0.215
# had_number_of_requests_for_new_text_fragment_la...             0.232
# had_downloaded_regular_flyers_before                           0.241
# metro_area_Phoenix                                             0.249
# had_added_events_manually_edited_events_before                 0.261
# metro_area_Dallas                                              0.264
# had_other_non_contactless_menu_qr_flyer_scans_b...             0.281
# had_posts_disliked_last_3_months                               0.306
# spot_category_Bar                                              0.311
# spot_category_Gastropub                                         0.32
# spot_category_Sports Bar                                       0.321
# had_online_orders_before                                        0.33
# had_posts_seen_before                                          0.335
# had_visited_special_page_before                                0.339
# metro_area_Milwaukee                                           0.339
# had_added_specials_edited_specials_before                      0.339
# spot_category_Irish Pub                                        0.355
# metro_area_Chicago                                             0.361
# had_posts_disliked_before                                      0.377
# had_visited_regular_flyers_page_last_3_months                  0.384
# spot_category_Steakhouse                                       0.388
# metro_area_Houston                                             0.393
# ...
# had_visited_food_page_before                                   0.649
# had_emails_sent_manually_scheduled_emails_sent_...             0.692
# had_consumer_job_listing_inquiries_last_2_months               0.717
# had_visited_stats_page_before                                  0.824
# had_posts_liked_before                                         0.826
# had_tickets_last_3_months                                      0.838
# had_qr_code_menu_scans_last_month                              0.849
# had_posts_seen_last_3_months                                   0.879
# had_downloaded_regular_flyers_last_3_months                    0.913
# had_visited_qrcode_flyers_page_last_3_months                   0.921
# ## without variables p value >= 0.2
#                                                    coef - AVERAGE  \
# variable
# their_own_website_no                                       -1.607
# had_posts_on_facebook_last_month                            -0.62
# Monthly                                                     0.995
# Website.Views.last.month.total.log2                        -0.197
# had_clicked_emails_last_3_months                           -0.598
# had_tickets_before                                         -0.639
# spot_category_Mexican / Latin                               0.656
# metro_area_Boston                                           0.797
# had_posts_seen_before                                        0.59
# had_preview_page_views_before                               0.639
# had_clicked_emails_before                                   0.452
# had_visited_qrcode_flyers_page_before                      -0.854
# their_own_website_dontKnow                                 -0.966
# had_posts_on_facebook_before                                0.425
# metro_area_Atlanta                                          -0.64
# had_posts_liked_last_3_months                              -0.485
# spot_category_Pub                                          -1.495
# had_visited_regular_flyers_page_before                      0.327
# Fb.page.likes.analysis.avg.log2                            -0.035
# had_visited_special_page_last_3_months                     -0.416
# had_changed_picture_or_text_last_3_months                  -0.435
# metro_area_Portland                                        -0.566
# had_downloaded_qrcode_flyers_before                        -0.982
# had_visited_admin_last_month                               -0.268
# had_reservations_submissions_last_month                    -0.673
# had_added_specials_edited_specials_last_3_months            0.482
# had_emails_sent_manually_scheduled_emails_sent_...         -0.312
# spot_category_Thai                                          0.642
# had_posts_disliked_before                                   0.242
# Instagram.Add.on                                            0.202
# had_reservations_submissions_before                         0.354
# spot_category_Sushi                                        -1.623
# metro_area_Detroit                                         -0.587
# had_catering_submissions_last_3_months                     -0.455
# had_visited_food_page_last_3_months                        -0.247
# metro_area_New Orleans                                      -1.58
# spot_category_Pizza                                        -0.537
# New.email.subscribers.allinclusive.last.month.d...         -0.064
# spot_category_Gastropub                                      0.56
# had_other_non_contactless_menu_qr_flyer_scans_l...          -1.23
# had_added_events_manually_edited_events_last_3_...         -0.388
# had_visited_inquiries_pages_last_3_months                  -0.297
# is_premium_plus                                            -0.205
# spot_category_American Restaurant / Bar                    -0.281
# metro_area_other                                           -0.357
# had_visited_stats_page_last_3_months                        0.262
# is_platform_only                                           -0.435
# spot_category_Sports Bar                                   -0.374
# had_added_events_manually_edited_events_before              0.213
# had_qr_code_menu_scans_before                              -0.414
# had_visited_admin_before                                    0.336
# had_changed_picture_or_text_before                          0.187
# had_added_specials_edited_specials_before                  -0.163
# had_posts_seen_last_3_months                                -0.15
# had_visited_regular_flyers_page_last_3_months              -0.181
# had_other_non_contactless_menu_qr_flyer_scans_b...          0.329
# had_visited_special_page_before                            -0.125
# had_emails_sent_manually_scheduled_emails_sent_...          0.097
# had_preview_page_views_last_3_months                       -0.096
# had_downloaded_qrcode_flyers_last_2_months                  0.392
# had_catering_submissions_before                            -0.106
# had_visited_food_page_before                               -0.081
# had_posts_liked_before                                      0.071
# had_posts_disliked_last_3_months                           -0.067
# had_qr_code_menu_scans_last_month                          -0.124
# had_visited_stats_page_before                               0.028
# had_tickets_last_3_months                                   0.034
# had_visited_inquiries_pages_before                           0.03
# had_visited_qrcode_flyers_page_last_3_months                0.021
#
#                                                    exp(coef) - AVERAGE  \
# variable
# their_own_website_no                                             0.201
# had_posts_on_facebook_last_month                                 0.538
# Monthly                                                          2.706
# Website.Views.last.month.total.log2                              0.821
# had_clicked_emails_last_3_months                                  0.55
# had_tickets_before                                               0.528
# spot_category_Mexican / Latin                                    1.929
# metro_area_Boston                                                2.221
# had_posts_seen_before                                            1.804
# had_preview_page_views_before                                    1.896
# had_clicked_emails_before                                        1.574
# had_visited_qrcode_flyers_page_before                            0.426
# their_own_website_dontKnow                                       0.382
# had_posts_on_facebook_before                                     1.531
# metro_area_Atlanta                                               0.528
# had_posts_liked_last_3_months                                    0.616
# spot_category_Pub                                                0.225
# had_visited_regular_flyers_page_before                           1.387
# Fb.page.likes.analysis.avg.log2                                  0.966
# had_visited_special_page_last_3_months                            0.66
# had_changed_picture_or_text_last_3_months                        0.647
# metro_area_Portland                                              0.569
# had_downloaded_qrcode_flyers_before                              0.375
# had_visited_admin_last_month                                     0.766
# had_reservations_submissions_last_month                          0.511
# had_added_specials_edited_specials_last_3_months                 1.619
# had_emails_sent_manually_scheduled_emails_sent_...               0.733
# spot_category_Thai                                               1.902
# had_posts_disliked_before                                        1.273
# Instagram.Add.on                                                 1.225
# had_reservations_submissions_before                              1.427
# spot_category_Sushi                                              0.197
# metro_area_Detroit                                               0.556
# had_catering_submissions_last_3_months                           0.635
# had_visited_food_page_last_3_months                              0.782
# metro_area_New Orleans                                           0.206
# spot_category_Pizza                                              0.585
# New.email.subscribers.allinclusive.last.month.d...               0.938
# spot_category_Gastropub                                          1.751
# had_other_non_contactless_menu_qr_flyer_scans_l...               0.293
# had_added_events_manually_edited_events_last_3_...               0.678
# had_visited_inquiries_pages_last_3_months                        0.743
# is_premium_plus                                                  0.815
# spot_category_American Restaurant / Bar                          0.755
# metro_area_other                                                   0.7
# had_visited_stats_page_last_3_months                               1.3
# is_platform_only                                                 0.647
# spot_category_Sports Bar                                         0.688
# had_added_events_manually_edited_events_before                   1.238
# had_qr_code_menu_scans_before                                    0.661
# had_visited_admin_before                                         1.402
# had_changed_picture_or_text_before                               1.206
# had_added_specials_edited_specials_before                         0.85
# had_posts_seen_last_3_months                                     0.863
# had_visited_regular_flyers_page_last_3_months                    0.835
# had_other_non_contactless_menu_qr_flyer_scans_b...               1.397
# had_visited_special_page_before                                  0.883
# had_emails_sent_manually_scheduled_emails_sent_...               1.103
# had_preview_page_views_last_3_months                              0.91
# had_downloaded_qrcode_flyers_last_2_months                        1.48
# had_catering_submissions_before                                    0.9
# had_visited_food_page_before                                     0.922
# had_posts_liked_before                                           1.074
# had_posts_disliked_last_3_months                                 0.935
# had_qr_code_menu_scans_last_month                                0.884
# had_visited_stats_page_before                                    1.029
# had_tickets_last_3_months                                        1.035
# had_visited_inquiries_pages_before                               1.031
# had_visited_qrcode_flyers_page_last_3_months                     1.021
#
#                                                    p value - AVERAGE
# variable
# their_own_website_no                                               0
# had_posts_on_facebook_last_month                                   0
# Monthly                                                            0
# Website.Views.last.month.total.log2                                0
# had_clicked_emails_last_3_months                                   0
# had_tickets_before                                                 0
# spot_category_Mexican / Latin                                  0.001
# metro_area_Boston                                              0.002
# had_posts_seen_before                                          0.002
# had_preview_page_views_before                                  0.002
# had_clicked_emails_before                                      0.005
# had_visited_qrcode_flyers_page_before                          0.005
# their_own_website_dontKnow                                     0.006
# had_posts_on_facebook_before                                   0.009
# metro_area_Atlanta                                             0.011
# had_posts_liked_last_3_months                                  0.023
# spot_category_Pub                                              0.037
# had_visited_regular_flyers_page_before                         0.041
# Fb.page.likes.analysis.avg.log2                                0.045
# had_visited_special_page_last_3_months                         0.046
# had_changed_picture_or_text_last_3_months                      0.048
# metro_area_Portland                                            0.049
# had_downloaded_qrcode_flyers_before                            0.054
# had_visited_admin_last_month                                   0.061
# had_reservations_submissions_last_month                        0.063
# had_added_specials_edited_specials_last_3_months               0.069
# had_emails_sent_manually_scheduled_emails_sent_...             0.072
# spot_category_Thai                                             0.085
# had_posts_disliked_before                                      0.086
# Instagram.Add.on                                               0.099
# had_reservations_submissions_before                            0.103
# spot_category_Sushi                                            0.108
# metro_area_Detroit                                             0.112
# had_catering_submissions_last_3_months                         0.113
# had_visited_food_page_last_3_months                            0.116
# metro_area_New Orleans                                         0.118
# spot_category_Pizza                                            0.121
# New.email.subscribers.allinclusive.last.month.d...             0.122
# spot_category_Gastropub                                        0.123
# had_other_non_contactless_menu_qr_flyer_scans_l...             0.124
# had_added_events_manually_edited_events_last_3_...             0.127
# had_visited_inquiries_pages_last_3_months                      0.132
# is_premium_plus                                                0.136
# spot_category_American Restaurant / Bar                         0.14
# metro_area_other                                               0.152
# had_visited_stats_page_last_3_months                           0.162
# is_platform_only                                               0.167
# spot_category_Sports Bar                                        0.17
# had_added_events_manually_edited_events_before                 0.171
# had_qr_code_menu_scans_before                                  0.177
# had_visited_admin_before                                       0.197
# had_changed_picture_or_text_before                             0.207
# had_added_specials_edited_specials_before                      0.271
# had_posts_seen_last_3_months                                   0.377
# had_visited_regular_flyers_page_last_3_months                  0.385
# had_other_non_contactless_menu_qr_flyer_scans_b...             0.392
# had_visited_special_page_before                                0.474
# had_emails_sent_manually_scheduled_emails_sent_...             0.529
# had_preview_page_views_last_3_months                           0.532
# had_downloaded_qrcode_flyers_last_2_months                      0.61
# had_catering_submissions_before                                0.631
# had_visited_food_page_before                                   0.632
# had_posts_liked_before                                         0.632
# had_posts_disliked_last_3_months                               0.715
# had_qr_code_menu_scans_last_month                              0.726
# had_visited_stats_page_before                                  0.772
# had_tickets_last_3_months                                      0.804
# had_visited_inquiries_pages_before                             0.839
# had_visited_qrcode_flyers_page_last_3_months                   0.942

# %% [markdown]
# # Average coefficients and p values for all combinations of variables - sorted by variable name

# %%
for i in range(0, len(final_summaries)):
    display(Markdown("## "+all_conditions_described[i]))
    display(final_summaries[i].sort_index())
# Out:
# ## with all initial variables
#                                                    coef - AVERAGE  \
# variable
# Annual Commitment with 2 semi-annual payments               -0.19
# Annual Prepay                                              -0.054
# Fb.page.likes.analysis.avg.log2                            -0.038
# Instagram.Add.on                                            0.211
# Monthly                                                     1.003
# New.email.subscriber.signups.last.month.div10                   0
# New.email.subscribers.allinclusive.last.month.d...         -0.062
# Opted.out.of.facebook                                       0.126
# SpotHopper_site_not_live_yet                               -0.168
# Website.Views.last.month.total.log2                        -0.223
# had_added_events_manually_edited_events_before              0.145
# had_added_events_manually_edited_events_last_3_...          -0.36
# had_added_food_edited_food_before                           0.162
# had_added_food_edited_food_last_3_months                    0.057
# had_added_specials_edited_specials_before                  -0.179
# had_added_specials_edited_specials_last_3_months            0.496
# had_bday_club_downloads_before                             -7.171
# had_bday_club_downloads_last_month                         -2.774
# had_catering_submissions_before                            -0.169
# had_catering_submissions_last_3_months                     -0.368
# had_changed_picture_or_text_before                          0.032
# had_changed_picture_or_text_last_3_months                  -0.184
# had_clicked_emails_before                                   0.411
# had_clicked_emails_last_3_months                            -0.57
# had_consumer_job_listing_inquiries_before                   0.298
# had_consumer_job_listing_inquiries_last_2_months             0.12
# had_downloaded_qrcode_flyers_before                        -0.157
# had_downloaded_qrcode_flyers_last_2_months                  0.449
# had_downloaded_regular_flyers_before                         0.21
# had_downloaded_regular_flyers_last_3_months                 0.063
# had_emails_sent_manually_scheduled_emails_sent_...          0.041
# had_emails_sent_manually_scheduled_emails_sent_...         -0.246
# had_feedback_submissions_before                            -8.874
# had_feedback_submissions_last_month                        -1.653
# had_flyer_posts_on_facebook_before                         -0.079
# had_flyer_posts_on_facebook_last_2_months                  -0.233
# had_incentive_downloads_before                             -8.837
# had_incentive_downloads_last_month                         -1.726
# had_number_of_requests_for_new_text_fragment_be...          0.088
# had_number_of_requests_for_new_text_fragment_la...          0.196
# had_online_orders_before                                     0.31
# had_online_orders_last_month                               -0.336
# had_opened_rewarding_stats_emails_before                    0.258
# had_opened_rewarding_stats_emails_last_2_months             0.186
# had_other_non_contactless_menu_qr_flyer_scans_b...          0.471
# had_other_non_contactless_menu_qr_flyer_scans_l...         -1.019
# had_posts_disliked_before                                   0.082
# had_posts_disliked_last_3_months                             0.21
# had_posts_liked_before                                      0.015
# had_posts_liked_last_3_months                              -0.491
# had_posts_on_facebook_before                                0.362
# had_posts_on_facebook_last_month                           -0.597
# had_posts_seen_before                                       0.267
# had_posts_seen_last_3_months                               -0.015
# had_preview_page_views_before                               0.527
# had_preview_page_views_last_3_months                       -0.127
# had_private_parties_submissions_before                     -0.039
# had_private_parties_submissions_last_2_months               0.003
# had_qr_code_menu_scans_before                              -0.458
# had_qr_code_menu_scans_last_month                           -0.04
# had_reservations_submissions_before                         0.358
# had_reservations_submissions_last_month                    -0.555
# had_tickets_before                                         -0.638
# had_tickets_last_3_months                                   0.021
# had_visited_admin_before                                    0.369
# had_visited_admin_last_month                                -0.19
# had_visited_events_page_before                               0.07
# had_visited_events_page_last_3_months                       0.066
# had_visited_food_page_before                               -0.124
# had_visited_food_page_last_3_months                        -0.207
# had_visited_inquiries_pages_before                          0.097
# had_visited_inquiries_pages_last_3_months                  -0.249
# had_visited_qrcode_flyers_page_before                      -0.841
# had_visited_qrcode_flyers_page_last_3_months               -0.017
# had_visited_regular_flyers_page_before                      0.225
# had_visited_regular_flyers_page_last_3_months              -0.206
# had_visited_special_page_before                            -0.215
# had_visited_special_page_last_3_months                     -0.394
# had_visited_stats_page_before                              -0.012
# had_visited_stats_page_last_3_months                         0.28
# is_corona                                                  -0.019
# is_platform_only                                           -0.483
# is_premium_plus                                            -0.198
# metro_area_Atlanta                                         -0.893
# metro_area_Austin                                          -0.177
# metro_area_Boston                                           0.669
# metro_area_Charleston                                       0.069
# metro_area_Charlotte                                        0.212
# metro_area_Chicago                                         -0.326
# metro_area_Dallas                                          -0.365
# metro_area_Denver                                          -0.417
# metro_area_Detroit                                         -0.704
# metro_area_Houston                                         -0.382
# metro_area_Los Angeles                                     -0.099
# metro_area_Milwaukee                                       -0.676
# metro_area_Minneapolis                                     -0.295
# metro_area_New Orleans                                     -1.863
# metro_area_New York                                        -0.049
# metro_area_Phoenix                                         -0.244
# metro_area_Portland                                        -0.728
# metro_area_Washington DC                                   -0.213
# metro_area_other                                           -0.483
# spot_category_American Restaurant                          -0.058
# spot_category_American Restaurant / Bar                    -0.251
# spot_category_Asian                                         -0.14
# spot_category_BBQ                                           0.088
# spot_category_Bar                                           0.183
# spot_category_Breakfast / Brunch                             0.18
# spot_category_Brewery                                       0.092
# spot_category_Cafe                                         -0.082
# spot_category_Gastropub                                     0.395
# spot_category_Irish Pub                                    -0.259
# spot_category_Italian                                      -0.045
# spot_category_Japanese                                      0.411
# spot_category_Mexican / Latin                               0.742
# spot_category_Pizza                                        -0.586
# spot_category_Pub                                          -1.617
# spot_category_Restaurant                                    0.022
# spot_category_Seafood                                      -0.022
# spot_category_Sports Bar                                   -0.261
# spot_category_Steakhouse                                   -0.632
# spot_category_Sushi                                        -1.468
# spot_category_Thai                                          0.821
# spot_category_other                                         0.123
# their_own_website_dontKnow                                  -1.04
# their_own_website_no                                       -1.957
#
#                                                    exp(coef) - AVERAGE  \
# variable
# Annual Commitment with 2 semi-annual payments                    0.828
# Annual Prepay                                                    0.948
# Fb.page.likes.analysis.avg.log2                                  0.963
# Instagram.Add.on                                                 1.236
# Monthly                                                          2.726
# New.email.subscriber.signups.last.month.div10                    1.001
# New.email.subscribers.allinclusive.last.month.d...                0.94
# Opted.out.of.facebook                                            1.134
# SpotHopper_site_not_live_yet                                     0.846
# Website.Views.last.month.total.log2                                0.8
# had_added_events_manually_edited_events_before                   1.156
# had_added_events_manually_edited_events_last_3_...               0.698
# had_added_food_edited_food_before                                1.177
# had_added_food_edited_food_last_3_months                         1.059
# had_added_specials_edited_specials_before                        0.837
# had_added_specials_edited_specials_last_3_months                 1.643
# had_bday_club_downloads_before                                   0.001
# had_bday_club_downloads_last_month                               0.063
# had_catering_submissions_before                                  0.844
# had_catering_submissions_last_3_months                           0.692
# had_changed_picture_or_text_before                               1.033
# had_changed_picture_or_text_last_3_months                        0.833
# had_clicked_emails_before                                        1.511
# had_clicked_emails_last_3_months                                 0.566
# had_consumer_job_listing_inquiries_before                        1.348
# had_consumer_job_listing_inquiries_last_2_months                 1.128
# had_downloaded_qrcode_flyers_before                              0.859
# had_downloaded_qrcode_flyers_last_2_months                       1.569
# had_downloaded_regular_flyers_before                             1.234
# had_downloaded_regular_flyers_last_3_months                      1.066
# had_emails_sent_manually_scheduled_emails_sent_...               1.043
# had_emails_sent_manually_scheduled_emails_sent_...               0.783
# had_feedback_submissions_before                                      0
# had_feedback_submissions_last_month                              0.194
# had_flyer_posts_on_facebook_before                               0.925
# had_flyer_posts_on_facebook_last_2_months                        0.794
# had_incentive_downloads_before                                       0
# had_incentive_downloads_last_month                               0.178
# had_number_of_requests_for_new_text_fragment_be...               1.093
# had_number_of_requests_for_new_text_fragment_la...               1.217
# had_online_orders_before                                         1.364
# had_online_orders_last_month                                     0.715
# had_opened_rewarding_stats_emails_before                         1.298
# had_opened_rewarding_stats_emails_last_2_months                  1.204
# had_other_non_contactless_menu_qr_flyer_scans_b...               1.609
# had_other_non_contactless_menu_qr_flyer_scans_l...               0.361
# had_posts_disliked_before                                        1.087
# had_posts_disliked_last_3_months                                 1.235
# had_posts_liked_before                                           1.016
# had_posts_liked_last_3_months                                    0.612
# had_posts_on_facebook_before                                     1.438
# had_posts_on_facebook_last_month                                 0.551
# had_posts_seen_before                                            1.314
# had_posts_seen_last_3_months                                     0.986
# had_preview_page_views_before                                    1.697
# had_preview_page_views_last_3_months                             0.881
# had_private_parties_submissions_before                           0.962
# had_private_parties_submissions_last_2_months                    1.003
# had_qr_code_menu_scans_before                                    0.633
# had_qr_code_menu_scans_last_month                                0.961
# had_reservations_submissions_before                              1.431
# had_reservations_submissions_last_month                          0.575
# had_tickets_before                                               0.529
# had_tickets_last_3_months                                        1.021
# had_visited_admin_before                                         1.452
# had_visited_admin_last_month                                     0.828
# had_visited_events_page_before                                   1.073
# had_visited_events_page_last_3_months                            1.068
# had_visited_food_page_before                                     0.884
# had_visited_food_page_last_3_months                              0.813
# had_visited_inquiries_pages_before                               1.103
# had_visited_inquiries_pages_last_3_months                         0.78
# had_visited_qrcode_flyers_page_before                            0.432
# had_visited_qrcode_flyers_page_last_3_months                     0.984
# had_visited_regular_flyers_page_before                           1.253
# had_visited_regular_flyers_page_last_3_months                    0.814
# had_visited_special_page_before                                  0.807
# had_visited_special_page_last_3_months                           0.675
# had_visited_stats_page_before                                    0.989
# had_visited_stats_page_last_3_months                             1.324
# is_corona                                                        0.982
# is_platform_only                                                 0.618
# is_premium_plus                                                  0.821
# metro_area_Atlanta                                               0.409
# metro_area_Austin                                                0.838
# metro_area_Boston                                                1.954
# metro_area_Charleston                                            1.074
# metro_area_Charlotte                                             1.239
# metro_area_Chicago                                               0.722
# metro_area_Dallas                                                0.694
# metro_area_Denver                                                 0.66
# metro_area_Detroit                                               0.495
# metro_area_Houston                                               0.683
# metro_area_Los Angeles                                           0.907
# metro_area_Milwaukee                                              0.51
# metro_area_Minneapolis                                           0.745
# metro_area_New Orleans                                           0.155
# metro_area_New York                                              0.952
# metro_area_Phoenix                                               0.784
# metro_area_Portland                                              0.484
# metro_area_Washington DC                                          0.81
# metro_area_other                                                 0.618
# spot_category_American Restaurant                                0.944
# spot_category_American Restaurant / Bar                          0.779
# spot_category_Asian                                              0.873
# spot_category_BBQ                                                1.094
# spot_category_Bar                                                1.202
# spot_category_Breakfast / Brunch                                 1.198
# spot_category_Brewery                                            1.097
# spot_category_Cafe                                               0.923
# spot_category_Gastropub                                          1.486
# spot_category_Irish Pub                                          0.773
# spot_category_Italian                                            0.957
# spot_category_Japanese                                           1.513
# spot_category_Mexican / Latin                                    2.103
# spot_category_Pizza                                              0.557
# spot_category_Pub                                                0.199
# spot_category_Restaurant                                         1.023
# spot_category_Seafood                                            0.979
# spot_category_Sports Bar                                         0.771
# spot_category_Steakhouse                                         0.532
# spot_category_Sushi                                              0.231
# spot_category_Thai                                               2.274
# spot_category_other                                              1.131
# their_own_website_dontKnow                                       0.354
# their_own_website_no                                             0.141
#
#                                                    p value - AVERAGE
# variable
# Annual Commitment with 2 semi-annual payments                  0.645
# Annual Prepay                                                  0.724
# Fb.page.likes.analysis.avg.log2                                0.043
# Instagram.Add.on                                               0.135
# Monthly                                                            0
# New.email.subscriber.signups.last.month.div10                  0.927
# New.email.subscribers.allinclusive.last.month.d...               0.3
# Opted.out.of.facebook                                          0.571
# SpotHopper_site_not_live_yet                                   0.656
# Website.Views.last.month.total.log2                                0
# had_added_events_manually_edited_events_before                 0.397
# had_added_events_manually_edited_events_last_3_...             0.215
# had_added_food_edited_food_before                              0.333
# had_added_food_edited_food_last_3_months                       0.787
# had_added_specials_edited_specials_before                      0.249
# had_added_specials_edited_specials_last_3_months               0.066
# had_bday_club_downloads_before                                 0.962
# had_bday_club_downloads_last_month                             0.992
# had_catering_submissions_before                                0.467
# had_catering_submissions_last_3_months                         0.208
# had_changed_picture_or_text_before                             0.858
# had_changed_picture_or_text_last_3_months                      0.491
# had_clicked_emails_before                                      0.015
# had_clicked_emails_last_3_months                                   0
# had_consumer_job_listing_inquiries_before                      0.262
# had_consumer_job_listing_inquiries_last_2_months               0.716
# had_downloaded_qrcode_flyers_before                             0.79
# had_downloaded_qrcode_flyers_last_2_months                     0.591
# had_downloaded_regular_flyers_before                           0.282
# had_downloaded_regular_flyers_last_3_months                    0.889
# had_emails_sent_manually_scheduled_emails_sent_...             0.758
# had_emails_sent_manually_scheduled_emails_sent_...             0.177
# had_feedback_submissions_before                                0.916
# had_feedback_submissions_last_month                            0.994
# had_flyer_posts_on_facebook_before                             0.664
# had_flyer_posts_on_facebook_last_2_months                      0.709
# had_incentive_downloads_before                                 0.936
# had_incentive_downloads_last_month                             0.995
# had_number_of_requests_for_new_text_fragment_be...             0.601
# had_number_of_requests_for_new_text_fragment_la...             0.519
# had_online_orders_before                                       0.329
# had_online_orders_last_month                                   0.464
# had_opened_rewarding_stats_emails_before                       0.491
# had_opened_rewarding_stats_emails_last_2_months                0.649
# had_other_non_contactless_menu_qr_flyer_scans_b...              0.26
# had_other_non_contactless_menu_qr_flyer_scans_l...              0.21
# had_posts_disliked_before                                      0.671
# had_posts_disliked_last_3_months                               0.369
# had_posts_liked_before                                         0.896
# had_posts_liked_last_3_months                                   0.04
# had_posts_on_facebook_before                                   0.041
# had_posts_on_facebook_last_month                                   0
# had_posts_seen_before                                          0.335
# had_posts_seen_last_3_months                                   0.911
# had_preview_page_views_before                                  0.059
# had_preview_page_views_last_3_months                           0.584
# had_private_parties_submissions_before                         0.828
# had_private_parties_submissions_last_2_months                  0.952
# had_qr_code_menu_scans_before                                  0.151
# had_qr_code_menu_scans_last_month                              0.911
# had_reservations_submissions_before                            0.116
# had_reservations_submissions_last_month                        0.141
# had_tickets_before                                                 0
# had_tickets_last_3_months                                      0.876
# had_visited_admin_before                                       0.184
# had_visited_admin_last_month                                   0.226
# had_visited_events_page_before                                 0.713
# had_visited_events_page_last_3_months                          0.753
# had_visited_food_page_before                                   0.526
# had_visited_food_page_last_3_months                            0.359
# had_visited_inquiries_pages_before                              0.58
# had_visited_inquiries_pages_last_3_months                       0.24
# had_visited_qrcode_flyers_page_before                          0.011
# had_visited_qrcode_flyers_page_last_3_months                   0.963
# had_visited_regular_flyers_page_before                         0.214
# had_visited_regular_flyers_page_last_3_months                  0.369
# had_visited_special_page_before                                0.278
# had_visited_special_page_last_3_months                         0.079
# had_visited_stats_page_before                                  0.838
# had_visited_stats_page_last_3_months                           0.151
# is_corona                                                      0.779
# is_platform_only                                               0.173
# is_premium_plus                                                0.199
# metro_area_Atlanta                                             0.002
# metro_area_Austin                                               0.54
# metro_area_Boston                                              0.021
# metro_area_Charleston                                          0.852
# metro_area_Charlotte                                             0.7
# metro_area_Chicago                                              0.29
# metro_area_Dallas                                              0.255
# metro_area_Denver                                              0.494
# metro_area_Detroit                                             0.075
# metro_area_Houston                                              0.29
# metro_area_Los Angeles                                         0.648
# metro_area_Milwaukee                                           0.267
# metro_area_Minneapolis                                         0.543
# metro_area_New Orleans                                         0.068
# metro_area_New York                                            0.806
# metro_area_Phoenix                                             0.303
# metro_area_Portland                                            0.026
# metro_area_Washington DC                                       0.607
# metro_area_other                                                0.09
# spot_category_American Restaurant                              0.829
# spot_category_American Restaurant / Bar                        0.306
# spot_category_Asian                                            0.797
# spot_category_BBQ                                              0.831
# spot_category_Bar                                              0.501
# spot_category_Breakfast / Brunch                                0.74
# spot_category_Brewery                                          0.841
# spot_category_Cafe                                             0.834
# spot_category_Gastropub                                        0.331
# spot_category_Irish Pub                                         0.51
# spot_category_Italian                                          0.852
# spot_category_Japanese                                         0.411
# spot_category_Mexican / Latin                                  0.003
# spot_category_Pizza                                            0.127
# spot_category_Pub                                              0.029
# spot_category_Restaurant                                       0.921
# spot_category_Seafood                                          0.931
# spot_category_Sports Bar                                       0.409
# spot_category_Steakhouse                                       0.417
# spot_category_Sushi                                            0.153
# spot_category_Thai                                             0.057
# spot_category_other                                            0.543
# their_own_website_dontKnow                                     0.006
# their_own_website_no                                               0
# ## without categorical variables with |coeff| < 0.2 and p value > 0.2; without numerical variables with |coeff| < 0.01 and p value > 0.2
#                                                    coef - AVERAGE  \
# variable
# Annual Commitment with 2 semi-annual payments              -0.253
# Fb.page.likes.analysis.avg.log2                            -0.036
# Instagram.Add.on                                            0.226
# Monthly                                                     1.021
# New.email.subscriber.signups.last.month.div10              -0.012
# New.email.subscribers.allinclusive.last.month.d...         -0.061
# SpotHopper_site_not_live_yet                               -0.277
# Website.Views.last.month.total.log2                        -0.219
# had_added_events_manually_edited_events_before              0.183
# had_added_events_manually_edited_events_last_3_...         -0.341
# had_added_specials_edited_specials_before                  -0.143
# had_added_specials_edited_specials_last_3_months             0.48
# had_bday_club_downloads_before                              -7.23
# had_bday_club_downloads_last_month                         -2.701
# had_catering_submissions_before                            -0.154
# had_catering_submissions_last_3_months                     -0.378
# had_changed_picture_or_text_before                          0.201
# had_changed_picture_or_text_last_3_months                  -0.415
# had_clicked_emails_before                                   0.416
# had_clicked_emails_last_3_months                           -0.587
# had_consumer_job_listing_inquiries_before                    0.32
# had_consumer_job_listing_inquiries_last_2_months            0.079
# had_downloaded_qrcode_flyers_before                        -0.141
# had_downloaded_qrcode_flyers_last_2_months                  0.453
# had_downloaded_regular_flyers_before                        0.223
# had_downloaded_regular_flyers_last_3_months                 0.009
# had_emails_sent_manually_scheduled_emails_sent_...          0.045
# had_emails_sent_manually_scheduled_emails_sent_...         -0.266
# had_feedback_submissions_before                             -8.83
# had_feedback_submissions_last_month                        -1.684
# had_flyer_posts_on_facebook_before                         -0.077
# had_flyer_posts_on_facebook_last_2_months                  -0.284
# had_incentive_downloads_before                             -8.858
# had_incentive_downloads_last_month                         -1.718
# had_number_of_requests_for_new_text_fragment_be...          0.113
# had_number_of_requests_for_new_text_fragment_la...          0.323
# had_online_orders_before                                    0.306
# had_online_orders_last_month                               -0.342
# had_opened_rewarding_stats_emails_before                    0.261
# had_opened_rewarding_stats_emails_last_2_months             0.193
# had_other_non_contactless_menu_qr_flyer_scans_b...          0.448
# had_other_non_contactless_menu_qr_flyer_scans_l...         -1.022
# had_posts_disliked_before                                   0.144
# had_posts_disliked_last_3_months                            0.209
# had_posts_liked_before                                      0.041
# had_posts_liked_last_3_months                              -0.522
# had_posts_on_facebook_before                                0.367
# had_posts_on_facebook_last_month                            -0.61
# had_posts_seen_before                                       0.267
# had_posts_seen_last_3_months                                -0.02
# had_preview_page_views_before                               0.544
# had_preview_page_views_last_3_months                       -0.141
# had_qr_code_menu_scans_before                               -0.46
# had_qr_code_menu_scans_last_month                          -0.059
# had_reservations_submissions_before                          0.34
# had_reservations_submissions_last_month                    -0.575
# had_tickets_before                                         -0.633
# had_tickets_last_3_months                                   0.023
# had_visited_admin_before                                    0.341
# had_visited_admin_last_month                               -0.208
# had_visited_food_page_before                               -0.077
# had_visited_food_page_last_3_months                        -0.227
# had_visited_inquiries_pages_before                          0.088
# had_visited_inquiries_pages_last_3_months                  -0.265
# had_visited_qrcode_flyers_page_before                      -0.852
# had_visited_qrcode_flyers_page_last_3_months               -0.025
# had_visited_regular_flyers_page_before                      0.268
# had_visited_regular_flyers_page_last_3_months               -0.19
# had_visited_special_page_before                            -0.173
# had_visited_special_page_last_3_months                     -0.413
# had_visited_stats_page_before                               0.005
# had_visited_stats_page_last_3_months                        0.271
# is_platform_only                                           -0.439
# is_premium_plus                                            -0.247
# metro_area_Atlanta                                         -0.788
# metro_area_Boston                                           0.732
# metro_area_Charleston                                       0.318
# metro_area_Charlotte                                        0.338
# metro_area_Chicago                                         -0.259
# metro_area_Dallas                                          -0.339
# metro_area_Denver                                          -0.323
# metro_area_Detroit                                         -0.649
# metro_area_Houston                                         -0.286
# metro_area_Milwaukee                                       -0.569
# metro_area_Minneapolis                                     -0.232
# metro_area_New Orleans                                     -1.767
# metro_area_Phoenix                                         -0.237
# metro_area_Portland                                         -0.61
# metro_area_Washington DC                                   -0.249
# metro_area_other                                           -0.403
# spot_category_American Restaurant / Bar                    -0.295
# spot_category_Asian                                        -0.349
# spot_category_Bar                                           0.228
# spot_category_Breakfast / Brunch                            0.225
# spot_category_Gastropub                                     0.374
# spot_category_Irish Pub                                    -0.334
# spot_category_Japanese                                      0.362
# spot_category_Mexican / Latin                               0.678
# spot_category_Pizza                                        -0.597
# spot_category_Pub                                          -1.612
# spot_category_Sports Bar                                   -0.277
# spot_category_Steakhouse                                   -0.648
# spot_category_Sushi                                        -1.543
# spot_category_Thai                                          0.732
# their_own_website_dontKnow                                 -1.043
# their_own_website_no                                       -1.816
#
#                                                    exp(coef) - AVERAGE  \
# variable
# Annual Commitment with 2 semi-annual payments                    0.777
# Fb.page.likes.analysis.avg.log2                                  0.965
# Instagram.Add.on                                                 1.253
# Monthly                                                          2.777
# New.email.subscriber.signups.last.month.div10                    0.988
# New.email.subscribers.allinclusive.last.month.d...               0.941
# SpotHopper_site_not_live_yet                                     0.758
# Website.Views.last.month.total.log2                              0.804
# had_added_events_manually_edited_events_before                   1.201
# had_added_events_manually_edited_events_last_3_...               0.712
# had_added_specials_edited_specials_before                        0.867
# had_added_specials_edited_specials_last_3_months                 1.618
# had_bday_club_downloads_before                                   0.001
# had_bday_club_downloads_last_month                               0.068
# had_catering_submissions_before                                  0.858
# had_catering_submissions_last_3_months                           0.685
# had_changed_picture_or_text_before                               1.222
# had_changed_picture_or_text_last_3_months                         0.66
# had_clicked_emails_before                                        1.517
# had_clicked_emails_last_3_months                                 0.556
# had_consumer_job_listing_inquiries_before                        1.378
# had_consumer_job_listing_inquiries_last_2_months                 1.082
# had_downloaded_qrcode_flyers_before                              0.872
# had_downloaded_qrcode_flyers_last_2_months                       1.575
# had_downloaded_regular_flyers_before                              1.25
# had_downloaded_regular_flyers_last_3_months                       1.01
# had_emails_sent_manually_scheduled_emails_sent_...               1.048
# had_emails_sent_manually_scheduled_emails_sent_...               0.768
# had_feedback_submissions_before                                      0
# had_feedback_submissions_last_month                              0.188
# had_flyer_posts_on_facebook_before                               0.928
# had_flyer_posts_on_facebook_last_2_months                        0.755
# had_incentive_downloads_before                                       0
# had_incentive_downloads_last_month                                0.18
# had_number_of_requests_for_new_text_fragment_be...                1.12
# had_number_of_requests_for_new_text_fragment_la...               1.381
# had_online_orders_before                                         1.359
# had_online_orders_last_month                                     0.711
# had_opened_rewarding_stats_emails_before                         1.298
# had_opened_rewarding_stats_emails_last_2_months                  1.213
# had_other_non_contactless_menu_qr_flyer_scans_b...               1.572
# had_other_non_contactless_menu_qr_flyer_scans_l...                0.36
# had_posts_disliked_before                                        1.156
# had_posts_disliked_last_3_months                                 1.235
# had_posts_liked_before                                           1.043
# had_posts_liked_last_3_months                                    0.594
# had_posts_on_facebook_before                                     1.445
# had_posts_on_facebook_last_month                                 0.543
# had_posts_seen_before                                            1.316
# had_posts_seen_last_3_months                                     0.981
# had_preview_page_views_before                                    1.729
# had_preview_page_views_last_3_months                             0.869
# had_qr_code_menu_scans_before                                    0.631
# had_qr_code_menu_scans_last_month                                0.943
# had_reservations_submissions_before                              1.406
# had_reservations_submissions_last_month                          0.563
# had_tickets_before                                               0.531
# had_tickets_last_3_months                                        1.024
# had_visited_admin_before                                         1.412
# had_visited_admin_last_month                                     0.813
# had_visited_food_page_before                                     0.926
# had_visited_food_page_last_3_months                              0.797
# had_visited_inquiries_pages_before                               1.094
# had_visited_inquiries_pages_last_3_months                        0.768
# had_visited_qrcode_flyers_page_before                            0.427
# had_visited_qrcode_flyers_page_last_3_months                     0.976
# had_visited_regular_flyers_page_before                           1.308
# had_visited_regular_flyers_page_last_3_months                    0.828
# had_visited_special_page_before                                  0.842
# had_visited_special_page_last_3_months                           0.662
# had_visited_stats_page_before                                    1.006
# had_visited_stats_page_last_3_months                             1.312
# is_platform_only                                                 0.647
# is_premium_plus                                                  0.781
# metro_area_Atlanta                                               0.455
# metro_area_Boston                                                 2.08
# metro_area_Charleston                                            1.375
# metro_area_Charlotte                                             1.404
# metro_area_Chicago                                               0.772
# metro_area_Dallas                                                0.714
# metro_area_Denver                                                0.725
# metro_area_Detroit                                               0.523
# metro_area_Houston                                               0.752
# metro_area_Milwaukee                                             0.567
# metro_area_Minneapolis                                           0.793
# metro_area_New Orleans                                           0.171
# metro_area_Phoenix                                               0.789
# metro_area_Portland                                              0.544
# metro_area_Washington DC                                          0.78
# metro_area_other                                                 0.668
# spot_category_American Restaurant / Bar                          0.745
# spot_category_Asian                                              0.707
# spot_category_Bar                                                1.256
# spot_category_Breakfast / Brunch                                 1.252
# spot_category_Gastropub                                          1.456
# spot_category_Irish Pub                                          0.717
# spot_category_Japanese                                           1.439
# spot_category_Mexican / Latin                                    1.972
# spot_category_Pizza                                              0.551
# spot_category_Pub                                                  0.2
# spot_category_Sports Bar                                         0.759
# spot_category_Steakhouse                                         0.525
# spot_category_Sushi                                              0.214
# spot_category_Thai                                               2.081
# their_own_website_dontKnow                                       0.353
# their_own_website_no                                             0.164
#
#                                                    p value - AVERAGE
# variable
# Annual Commitment with 2 semi-annual payments                  0.525
# Fb.page.likes.analysis.avg.log2                                 0.05
# Instagram.Add.on                                               0.089
# Monthly                                                            0
# New.email.subscriber.signups.last.month.div10                   0.75
# New.email.subscribers.allinclusive.last.month.d...             0.168
# SpotHopper_site_not_live_yet                                   0.447
# Website.Views.last.month.total.log2                                0
# had_added_events_manually_edited_events_before                 0.261
# had_added_events_manually_edited_events_last_3_...             0.196
# had_added_specials_edited_specials_before                      0.339
# had_added_specials_edited_specials_last_3_months               0.072
# had_bday_club_downloads_before                                 0.961
# had_bday_club_downloads_last_month                             0.992
# had_catering_submissions_before                                  0.5
# had_catering_submissions_last_3_months                         0.191
# had_changed_picture_or_text_before                              0.18
# had_changed_picture_or_text_last_3_months                       0.06
# had_clicked_emails_before                                      0.012
# had_clicked_emails_last_3_months                                   0
# had_consumer_job_listing_inquiries_before                      0.215
# had_consumer_job_listing_inquiries_last_2_months               0.808
# had_downloaded_qrcode_flyers_before                            0.808
# had_downloaded_qrcode_flyers_last_2_months                     0.587
# had_downloaded_regular_flyers_before                           0.241
# had_downloaded_regular_flyers_last_3_months                    0.942
# had_emails_sent_manually_scheduled_emails_sent_...             0.733
# had_emails_sent_manually_scheduled_emails_sent_...              0.14
# had_feedback_submissions_before                                0.917
# had_feedback_submissions_last_month                            0.994
# had_flyer_posts_on_facebook_before                              0.64
# had_flyer_posts_on_facebook_last_2_months                      0.647
# had_incentive_downloads_before                                 0.936
# had_incentive_downloads_last_month                             0.996
# had_number_of_requests_for_new_text_fragment_be...             0.454
# had_number_of_requests_for_new_text_fragment_la...             0.232
# had_online_orders_before                                        0.33
# had_online_orders_last_month                                   0.448
# had_opened_rewarding_stats_emails_before                       0.473
# had_opened_rewarding_stats_emails_last_2_months                0.634
# had_other_non_contactless_menu_qr_flyer_scans_b...             0.281
# had_other_non_contactless_menu_qr_flyer_scans_l...             0.207
# had_posts_disliked_before                                      0.377
# had_posts_disliked_last_3_months                               0.306
# had_posts_liked_before                                         0.802
# had_posts_liked_last_3_months                                  0.019
# had_posts_on_facebook_before                                   0.032
# had_posts_on_facebook_last_month                                   0
# had_posts_seen_before                                          0.335
# had_posts_seen_last_3_months                                    0.88
# had_preview_page_views_before                                  0.049
# had_preview_page_views_last_3_months                           0.504
# had_qr_code_menu_scans_before                                  0.144
# had_qr_code_menu_scans_last_month                              0.868
# had_reservations_submissions_before                            0.117
# had_reservations_submissions_last_month                        0.113
# had_tickets_before                                                 0
# had_tickets_last_3_months                                      0.861
# had_visited_admin_before                                       0.208
# had_visited_admin_last_month                                   0.158
# had_visited_food_page_before                                   0.658
# had_visited_food_page_last_3_months                            0.157
# had_visited_inquiries_pages_before                             0.572
# had_visited_inquiries_pages_last_3_months                      0.202
# had_visited_qrcode_flyers_page_before                          0.008
# had_visited_qrcode_flyers_page_last_3_months                   0.953
# had_visited_regular_flyers_page_before                         0.106
# had_visited_regular_flyers_page_last_3_months                  0.384
# ...
# spot_category_Japanese                                         0.387
# spot_category_Mexican / Latin                                  0.001
# spot_category_Pizza                                            0.084
# spot_category_Pub                                              0.025
# spot_category_Sports Bar                                       0.342
# spot_category_Steakhouse                                        0.39
# spot_category_Sushi                                            0.122
# spot_category_Thai                                             0.065
# their_own_website_dontKnow                                     0.004
# their_own_website_no                                               0
# ## without variables p value >= 0.2
#                                                    coef - AVERAGE  \
# variable
# Fb.page.likes.analysis.avg.log2                            -0.035
# Instagram.Add.on                                            0.202
# Monthly                                                     0.995
# New.email.subscribers.allinclusive.last.month.d...         -0.064
# Website.Views.last.month.total.log2                        -0.197
# had_added_events_manually_edited_events_before              0.213
# had_added_events_manually_edited_events_last_3_...         -0.388
# had_added_specials_edited_specials_before                  -0.163
# had_added_specials_edited_specials_last_3_months            0.482
# had_catering_submissions_before                            -0.106
# had_catering_submissions_last_3_months                     -0.455
# had_changed_picture_or_text_before                          0.187
# had_changed_picture_or_text_last_3_months                  -0.435
# had_clicked_emails_before                                   0.452
# had_clicked_emails_last_3_months                           -0.598
# had_downloaded_qrcode_flyers_before                        -0.982
# had_downloaded_qrcode_flyers_last_2_months                  0.392
# had_emails_sent_manually_scheduled_emails_sent_...          0.097
# had_emails_sent_manually_scheduled_emails_sent_...         -0.312
# had_other_non_contactless_menu_qr_flyer_scans_b...          0.329
# had_other_non_contactless_menu_qr_flyer_scans_l...          -1.23
# had_posts_disliked_before                                   0.242
# had_posts_disliked_last_3_months                           -0.067
# had_posts_liked_before                                      0.071
# had_posts_liked_last_3_months                              -0.485
# had_posts_on_facebook_before                                0.425
# had_posts_on_facebook_last_month                            -0.62
# had_posts_seen_before                                        0.59
# had_posts_seen_last_3_months                                -0.15
# had_preview_page_views_before                               0.639
# had_preview_page_views_last_3_months                       -0.096
# had_qr_code_menu_scans_before                              -0.414
# had_qr_code_menu_scans_last_month                          -0.124
# had_reservations_submissions_before                         0.354
# had_reservations_submissions_last_month                    -0.673
# had_tickets_before                                         -0.639
# had_tickets_last_3_months                                   0.034
# had_visited_admin_before                                    0.336
# had_visited_admin_last_month                               -0.268
# had_visited_food_page_before                               -0.081
# had_visited_food_page_last_3_months                        -0.247
# had_visited_inquiries_pages_before                           0.03
# had_visited_inquiries_pages_last_3_months                  -0.297
# had_visited_qrcode_flyers_page_before                      -0.854
# had_visited_qrcode_flyers_page_last_3_months                0.021
# had_visited_regular_flyers_page_before                      0.327
# had_visited_regular_flyers_page_last_3_months              -0.181
# had_visited_special_page_before                            -0.125
# had_visited_special_page_last_3_months                     -0.416
# had_visited_stats_page_before                               0.028
# had_visited_stats_page_last_3_months                        0.262
# is_platform_only                                           -0.435
# is_premium_plus                                            -0.205
# metro_area_Atlanta                                          -0.64
# metro_area_Boston                                           0.797
# metro_area_Detroit                                         -0.587
# metro_area_New Orleans                                      -1.58
# metro_area_Portland                                        -0.566
# metro_area_other                                           -0.357
# spot_category_American Restaurant / Bar                    -0.281
# spot_category_Gastropub                                      0.56
# spot_category_Mexican / Latin                               0.656
# spot_category_Pizza                                        -0.537
# spot_category_Pub                                          -1.495
# spot_category_Sports Bar                                   -0.374
# spot_category_Sushi                                        -1.623
# spot_category_Thai                                          0.642
# their_own_website_dontKnow                                 -0.966
# their_own_website_no                                       -1.607
#
#                                                    exp(coef) - AVERAGE  \
# variable
# Fb.page.likes.analysis.avg.log2                                  0.966
# Instagram.Add.on                                                 1.225
# Monthly                                                          2.706
# New.email.subscribers.allinclusive.last.month.d...               0.938
# Website.Views.last.month.total.log2                              0.821
# had_added_events_manually_edited_events_before                   1.238
# had_added_events_manually_edited_events_last_3_...               0.678
# had_added_specials_edited_specials_before                         0.85
# had_added_specials_edited_specials_last_3_months                 1.619
# had_catering_submissions_before                                    0.9
# had_catering_submissions_last_3_months                           0.635
# had_changed_picture_or_text_before                               1.206
# had_changed_picture_or_text_last_3_months                        0.647
# had_clicked_emails_before                                        1.574
# had_clicked_emails_last_3_months                                  0.55
# had_downloaded_qrcode_flyers_before                              0.375
# had_downloaded_qrcode_flyers_last_2_months                        1.48
# had_emails_sent_manually_scheduled_emails_sent_...               1.103
# had_emails_sent_manually_scheduled_emails_sent_...               0.733
# had_other_non_contactless_menu_qr_flyer_scans_b...               1.397
# had_other_non_contactless_menu_qr_flyer_scans_l...               0.293
# had_posts_disliked_before                                        1.273
# had_posts_disliked_last_3_months                                 0.935
# had_posts_liked_before                                           1.074
# had_posts_liked_last_3_months                                    0.616
# had_posts_on_facebook_before                                     1.531
# had_posts_on_facebook_last_month                                 0.538
# had_posts_seen_before                                            1.804
# had_posts_seen_last_3_months                                     0.863
# had_preview_page_views_before                                    1.896
# had_preview_page_views_last_3_months                              0.91
# had_qr_code_menu_scans_before                                    0.661
# had_qr_code_menu_scans_last_month                                0.884
# had_reservations_submissions_before                              1.427
# had_reservations_submissions_last_month                          0.511
# had_tickets_before                                               0.528
# had_tickets_last_3_months                                        1.035
# had_visited_admin_before                                         1.402
# had_visited_admin_last_month                                     0.766
# had_visited_food_page_before                                     0.922
# had_visited_food_page_last_3_months                              0.782
# had_visited_inquiries_pages_before                               1.031
# had_visited_inquiries_pages_last_3_months                        0.743
# had_visited_qrcode_flyers_page_before                            0.426
# had_visited_qrcode_flyers_page_last_3_months                     1.021
# had_visited_regular_flyers_page_before                           1.387
# had_visited_regular_flyers_page_last_3_months                    0.835
# had_visited_special_page_before                                  0.883
# had_visited_special_page_last_3_months                            0.66
# had_visited_stats_page_before                                    1.029
# had_visited_stats_page_last_3_months                               1.3
# is_platform_only                                                 0.647
# is_premium_plus                                                  0.815
# metro_area_Atlanta                                               0.528
# metro_area_Boston                                                2.221
# metro_area_Detroit                                               0.556
# metro_area_New Orleans                                           0.206
# metro_area_Portland                                              0.569
# metro_area_other                                                   0.7
# spot_category_American Restaurant / Bar                          0.755
# spot_category_Gastropub                                          1.751
# spot_category_Mexican / Latin                                    1.929
# spot_category_Pizza                                              0.585
# spot_category_Pub                                                0.225
# spot_category_Sports Bar                                         0.688
# spot_category_Sushi                                              0.197
# spot_category_Thai                                               1.902
# their_own_website_dontKnow                                       0.382
# their_own_website_no                                             0.201
#
#                                                    p value - AVERAGE
# variable
# Fb.page.likes.analysis.avg.log2                                0.045
# Instagram.Add.on                                               0.099
# Monthly                                                            0
# New.email.subscribers.allinclusive.last.month.d...             0.122
# Website.Views.last.month.total.log2                                0
# had_added_events_manually_edited_events_before                 0.171
# had_added_events_manually_edited_events_last_3_...             0.127
# had_added_specials_edited_specials_before                      0.271
# had_added_specials_edited_specials_last_3_months               0.069
# had_catering_submissions_before                                0.631
# had_catering_submissions_last_3_months                         0.113
# had_changed_picture_or_text_before                             0.207
# had_changed_picture_or_text_last_3_months                      0.048
# had_clicked_emails_before                                      0.005
# had_clicked_emails_last_3_months                                   0
# had_downloaded_qrcode_flyers_before                            0.054
# had_downloaded_qrcode_flyers_last_2_months                      0.61
# had_emails_sent_manually_scheduled_emails_sent_...             0.529
# had_emails_sent_manually_scheduled_emails_sent_...             0.072
# had_other_non_contactless_menu_qr_flyer_scans_b...             0.392
# had_other_non_contactless_menu_qr_flyer_scans_l...             0.124
# had_posts_disliked_before                                      0.086
# had_posts_disliked_last_3_months                               0.715
# had_posts_liked_before                                         0.632
# had_posts_liked_last_3_months                                  0.023
# had_posts_on_facebook_before                                   0.009
# had_posts_on_facebook_last_month                                   0
# had_posts_seen_before                                          0.002
# had_posts_seen_last_3_months                                   0.377
# had_preview_page_views_before                                  0.002
# had_preview_page_views_last_3_months                           0.532
# had_qr_code_menu_scans_before                                  0.177
# had_qr_code_menu_scans_last_month                              0.726
# had_reservations_submissions_before                            0.103
# had_reservations_submissions_last_month                        0.063
# had_tickets_before                                                 0
# had_tickets_last_3_months                                      0.804
# had_visited_admin_before                                       0.197
# had_visited_admin_last_month                                   0.061
# had_visited_food_page_before                                   0.632
# had_visited_food_page_last_3_months                            0.116
# had_visited_inquiries_pages_before                             0.839
# had_visited_inquiries_pages_last_3_months                      0.132
# had_visited_qrcode_flyers_page_before                          0.005
# had_visited_qrcode_flyers_page_last_3_months                   0.942
# had_visited_regular_flyers_page_before                         0.041
# had_visited_regular_flyers_page_last_3_months                  0.385
# had_visited_special_page_before                                0.474
# had_visited_special_page_last_3_months                         0.046
# had_visited_stats_page_before                                  0.772
# had_visited_stats_page_last_3_months                           0.162
# is_platform_only                                               0.167
# is_premium_plus                                                0.136
# metro_area_Atlanta                                             0.011
# metro_area_Boston                                              0.002
# metro_area_Detroit                                             0.112
# metro_area_New Orleans                                         0.118
# metro_area_Portland                                            0.049
# metro_area_other                                               0.152
# spot_category_American Restaurant / Bar                         0.14
# spot_category_Gastropub                                        0.123
# spot_category_Mexican / Latin                                  0.001
# spot_category_Pizza                                            0.121
# spot_category_Pub                                              0.037
# spot_category_Sports Bar                                        0.17
# spot_category_Sushi                                            0.108
# spot_category_Thai                                             0.085
# their_own_website_dontKnow                                     0.006
# their_own_website_no                                               0
